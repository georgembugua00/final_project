# %%
from IPython.display import Image

image = Image(filename="project_data\data\_b360a014-07f1-4648-acb3-dc80be4cf7ee.jpeg")

image

# %% [markdown]
# #Introduction
# Microsoft is amongst the top leading technological companies in the world. With over 600 offices in more than 190 countries and revenues of over $150 billon dollars, Microsoft is a well resourced company that can enter and captive any market
#
# #Business Problem
# Microsoft currently is lack the required insights, facts and figures required to enter the film industry efficiently and effectivly. Inorder for the CEO Satya Nadella to create and implement strategic goals and objectives required to venture into this industry he will need actionable insights based on existing market data.

# %% [markdown]
# Data Understanding
#
# The data sets and databases provide by Microsoft aids us in creating data insights. The datasets are from five popular movie rating and reviews platforms, they are as follows:
#     1.IMDB
#     2. Rotten Tomatoes
#     3.Box Office Mojo
#     4.TheMovieDB
#     5.The Numbers
#
# the data is save in three main file types which are CSV, SQL Database and TSV.

# %%
#Lets import the important libraie
import pandas as pd
import numpy as np 
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# The Box Office Dataset
#
# This dataset contains the movie name, Studio company name and its domestic and foreign gross and which year it was released.
#
# Lets Understand our dataset and get a directin of what infomation we require.
#
# Load the data using pandas first

# %%
bom_movie_df = pd.read_csv("../../bom.movie_gross.csv/bom.movie_gross.csv")

bom_movie_df = pd.DataFrame(bom_movie_df)
bom_movie_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\George Mbugua\OneDrive\Documents\Project_Phase1\final_project\Project_Phase1.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/George%20Mbugua/OneDrive/Documents/Project_Phase1/final_project/Project_Phase1.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> bom_movie_df = pd.read_csv("../../bom.movie_gross.csv/bom.movie_gross.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/George%20Mbugua/OneDrive/Documents/Project_Phase1/final_project/Project_Phase1.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> bom_movie_df = pd.DataFrame(bom_movie_df)
#       <a href='vscode-notebook-cell:/c%3A/Users/George%20Mbugua/OneDrive/Documents/Project_Phase1/final_project/Project_Phase1.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> bom_movie_df
#
# ...
